# %%
from keras.datasets import boston_housing

# %%
train, test = boston_housing.load_data()

# %%
import seaborn as sns
import pandas as pd

# %%
df = pd.DataFrame(train[0])
df = pd.melt(df, value_vars=df.columns)
df
# Out:
#       variable     value
# 0            0   1.23247
# 1            0   0.02177
# 2            0   4.89822
# 3            0   0.03961
# 4            0   3.69311
# ...        ...       ...
# 5247        12  16.20000
# 5248        12   6.59000
# 5249        12   7.83000
# 5250        12  15.79000
# 5251        12   4.38000
#
# [5252 rows x 2 columns]

# %%
grid = sns.FacetGrid(df, col="variable", sharex=False, sharey=False)
grid.map(sns.histplot, "value", bins=10)
